# %% [markdown]
# <a href="https://colab.research.google.com/github/has97/first/blob/master/Faceexpression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-7fb7494e-ef3c-4b6f-b838-5d4065b9410b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fb7494e-ef3c-4b6f-b838-5d4065b9410b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train (2).zip to train (2).zip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-292f82be1b7a> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 uploaded = files.upload()
#       4
#       5 for fn in uploaded.keys():
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      75     result = _output.eval_js(
# ...

# %%
# !apt install unzip
# !unzip /content/train.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/train/Sad/3729.jpg
#  extracting: /content/train/Sad/373.jpg
#  extracting: /content/train/Sad/3730.jpg
#  extracting: /content/train/Sad/3731.jpg
#  extracting: /content/train/Sad/3732.jpg
#  extracting: /content/train/Sad/3733.jpg
#  extracting: /content/train/Sad/3734.jpg
#  extracting: /content/train/Sad/3735.jpg
#  extracting: /content/train/Sad/3736.jpg
#  extracting: /content/train/Sad/3737.jpg
#  extracting: /content/train/Sad/3738.jpg
#  extracting: /content/train/Sad/3739.jpg
#  extracting: /content/train/Sad/374.jpg
#  extracting: /content/train/Sad/3740.jpg
#  extracting: /content/train/Sad/3741.jpg
#  extracting: /content/train/Sad/3742.jpg
#  extracting: /content/train/Sad/3743.jpg
#  extracting: /content/train/Sad/3744.jpg
#  extracting: /content/train/Sad/3745.jpg
#  extracting: /content/train/Sad/3746.jpg
#  extracting: /content/train/Sad/3747.jpg
#  extracting: /content/train/Sad/3748.jpg
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    fill_mode ="nearest",
    horizontal_flip = True,
    validation_split=0.15)
train_generator = train_datagen.flow_from_directory(
    "/content/train",
    target_size=(224,224),
    batch_size=16,
    class_mode='categorical',
    subset='training')
validation_generator = train_datagen.flow_from_directory(
    "/content/train", 
    target_size=(224,224),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 18582 images belonging to 5 classes.
# Found 3276 images belonging to 5 classes.

# %%
import tensorflow as tf
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer,GlobalAveragePooling1D
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from keras.applications.mobilenet import MobileNet
model1 = MobileNet(include_top=False , weights='imagenet',input_shape=(224,224,3))
for layer in model1.layers[0:15]:
    layer.trainable=False
for layer in model1.layers[15:]:
    layer.trainable=True
#model1.trainable=False  
x=Flatten()(model1.output)
output=Dense(5,activation='softmax')(x)
model=Model(inputs=model1.input,outputs=output)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.fit_generator(train_generator, epochs=100,validation_data=validation_generator)
# Out:
# ...
# 17227776/17225924 [==============================] - 1s 0us/step
# Epoch 1/100
# 1162/1162 [==============================] - 349s 301ms/step - loss: 1.7936 - accuracy: 0.4637 - val_loss: 0.9922 - val_accuracy: 0.4615
# Epoch 2/100
# 1162/1162 [==============================] - 340s 293ms/step - loss: 1.0668 - accuracy: 0.5810 - val_loss: 1.2634 - val_accuracy: 0.5534
# Epoch 3/100
# 1162/1162 [==============================] - 341s 293ms/step - loss: 0.9779 - accuracy: 0.6146 - val_loss: 1.7311 - val_accuracy: 0.5027
# Epoch 4/100
# 1162/1162 [==============================] - 340s 293ms/step - loss: 0.9223 - accuracy: 0.6415 - val_loss: 3.2826 - val_accuracy: 0.3074
# Epoch 5/100
# 1162/1162 [==============================] - 340s 292ms/step - loss: 1.0625 - accuracy: 0.6076 - val_loss: 1.4158 - val_accuracy: 0.3565
# Epoch 6/100
# 1162/1162 [==============================] - 340s 293ms/step - loss: 0.9800 - accuracy: 0.6277 - val_loss: 1.3810 - val_accuracy: 0.5888
# Epoch 7/100
# ...

# %%
from keras.applications.vgg16 import VGG16
model1 = VGG16(include_top=False , weights='imagenet',input_shape=(224,224,3))
# Out:
# ...
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
model1.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_4 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
train_generator.classes
# Out:
# array([1, 1, 1, ..., 5, 5, 5], dtype=int32)

# %%
train_generator.class_indices
import os
import shutil
os.listdir("/content/train")
shutil.rmtree("/content/train/.ipynb_checkpoints")
